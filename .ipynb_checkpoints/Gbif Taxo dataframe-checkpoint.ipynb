# %%
Taxo = open("simple2.txt","w+")

# %%
file_contents = Taxo.read()
print(file_contents)

# %%
import pandas as pd

# %%
df =pd.read_fwf("simple3.txt", sep = " ")

# %%
dir(pd)
# Out:
# ['Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NaT',
#  'Panel',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseDtype',
#  'SparseSeries',
#  'TimeGrouper',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_hashtable',
#  '_lib',
#  '_libs',
# ...

# %%
df.head()
# Out:
#   11\t7707728\t\N\tt\tSYNONYM\tPHYLUM\t{}\tdaacce49-b206-469b-8dc2-2257719f3afa\tSOURCE\t117196348\t6\t7707728\t\N\t\N\t\N\t\N\t\N\t4696769\tGinkgophyta\tGinkgophyta\tGinkgophyta\t\N\t\N\t\N\t\N\t\N\t\N\t\N\t\N\t{}  \
# 0  507\t7947184\t\N\tf\tACCEPTED\tORDER\t{}\t7ea2...
# 1  133\t14\t\N\tf\tACCEPTED\tCLASS\t{}\t7ddf754f-...
# 2  597\t7073563\t\N\tf\tACCEPTED\tORDER\t{}\t7ea2...
# 3  558\t7073593\t\N\tf\tACCEPTED\tORDER\t{}\t7ea2...
# 4  1084\t258\t\N\tf\tACCEPTED\tORDER\t{}\t7ea2158...
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10
# ...
