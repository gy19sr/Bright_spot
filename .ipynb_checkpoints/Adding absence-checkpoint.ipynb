# %%
import pandas as pd

# %%
df = pd.read_csv('inverts_database_CSV.csv', encoding = "ISO-8859-1", engine='python')

# %%
df.head()
# Out:
#   the_source  Ecoregion     country  region sitename         Lat        Lon  \
# 0        LTO        NaN  Mozambique  Komame      Pao  -24.067983  35.053267
# 1        LTO        NaN  Mozambique  Komame      Pao  -24.067983  35.053267
# 2        LTO        NaN  Mozambique  Komame  Neptune  -24.066992  35.503783
# 3        LTO        NaN  Mozambique  Komame  Neptune  -24.066992  35.503783
# 4        LTO        NaN  Mozambique  Komame  Neptune  -24.066992  35.503783
#
#    management             Method    Year  ... Abundance  t_Length t_Width  \
# 0         NaN  transect quadrats  2016.0  ...       NaN      80.0       5
# 1         NaN  transect quadrats  2016.0  ...       NaN      80.0       5
# 2         NaN  transect quadrats  2016.0  ...       NaN      80.0       5
# 3         NaN  transect quadrats  2016.0  ...       NaN      80.0       5
# 4         NaN  transect quadrats  2016.0  ...       NaN      80.0       5
#
#   Transect_area total number of transect total transect area den_per_100m2  \
# 0           400                      1.0               400.0           NaN
# 1           400                      1.0               400.0           NaN
# 2           400                      1.0               400.0           NaN
# 3           400                      1.0               400.0           NaN
# 4           400                      1.0               400.0           NaN
#
#   den_for_transect_#permeter density_for_summed_transect area_#permeter  \
# 0                     0.0025                                        NaN
# 1                      0.095                                        NaN
# 2                      0.005                                        NaN
# 3                     0.0025                                        NaN
# 4                     0.0175                                        NaN
#
#   den_per_HA
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 32 columns]

# %%
df = df.drop(["Abundance","Method","Ecoregion","habitat_type","management"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-065a992158ea> in <module>
# ----> 1 df = df.drop(["Abundance","Method","Ecoregion","habitat_type","managment"], axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4963             if errors != 'ignore':
#    4964                 raise KeyError(
# -> 4965                     '{} not found in axis'.format(labels[mask]))
#    4966             indexer = indexer[~mask]
#    4967         return self.delete(indexer)
#
# KeyError: "['managment'] not found in axis"

# %%
for col in df.columns: 
    print(col)
# Out:
# the_source
# Ecoregion
# country
# region
# sitename
# Lat
# Lon
# management
# Year
# Date
# habitat_type
# depth_m
# common name
# Phylum
# Class
# Order
# Family
# Genus
# genus species
# Count
# transect
# t_Length
# t_Width
# Transect_area
# total number of transect
# total transect area
# den_per_100m2
# den_for_transect_#permeter
# density_for_summed_transect area_#permeter
# den_per_HA

# %%
df = pd.DataFrame(df)

# %%
 df.head()
# Out:
#   the_source  Ecoregion     country  region sitename         Lat        Lon  \
# 0        LTO        NaN  Mozambique  Komame      Pao  -24.067983  35.053267
# 1        LTO        NaN  Mozambique  Komame      Pao  -24.067983  35.053267
# 2        LTO        NaN  Mozambique  Komame  Neptune  -24.066992  35.503783
# 3        LTO        NaN  Mozambique  Komame  Neptune  -24.066992  35.503783
# 4        LTO        NaN  Mozambique  Komame  Neptune  -24.066992  35.503783
#
#    management    Year       Date  ...  t_Length t_Width Transect_area  \
# 0         NaN  2016.0   8-Aug-16  ...      80.0       5           400
# 1         NaN  2016.0   1-Sep-16  ...      80.0       5           400
# 2         NaN  2016.0   1-Sep-16  ...      80.0       5           400
# 3         NaN  2016.0   1-Sep-16  ...      80.0       5           400
# 4         NaN  2016.0  10-Aug-16  ...      80.0       5           400
#
#   total number of transect total transect area den_per_100m2  \
# 0                      1.0               400.0           NaN
# 1                      1.0               400.0           NaN
# 2                      1.0               400.0           NaN
# 3                      1.0               400.0           NaN
# 4                      1.0               400.0           NaN
#
#   den_for_transect_#permeter density_for_summed_transect area_#permeter  \
# 0                     0.0025                                        NaN
# 1                      0.095                                        NaN
# 2                      0.005                                        NaN
# 3                     0.0025                                        NaN
# 4                     0.0175                                        NaN
#
#   den_per_HA id
# 0        NaN  1
# 1        NaN  2
# 2        NaN  3
# 3        NaN  4
# 4        NaN  5
#
# [5 rows x 31 columns]

# %%
df["id"] = df.index + 1
